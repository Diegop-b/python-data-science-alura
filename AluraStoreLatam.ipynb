# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
ingreso_tienda1 = tienda["Precio"].sum()
ingreso_tienda2 = tienda2["Precio"].sum()
ingreso_tienda3 = tienda3["Precio"].sum()
ingreso_tienda4 = tienda4["Precio"].sum()

# Mostrar resultados
print(f"Ingreso total de la Tienda 1: ${ingreso_tienda1:,.2f}")
print(f"Ingreso total de la Tienda 2: ${ingreso_tienda2:,.2f}")
print(f"Ingreso total de la Tienda 3: ${ingreso_tienda3:,.2f}")
print(f"Ingreso total de la Tienda 4: ${ingreso_tienda4:,.2f}")
# Out:
# Ingreso total de la Tienda 1: $1,150,880,400.00
# Ingreso total de la Tienda 2: $1,116,343,500.00
# Ingreso total de la Tienda 3: $1,098,019,600.00
# Ingreso total de la Tienda 4: $1,038,375,700.00

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# # 2. Ventas por categoría

# %%
print("Tienda 1 - Ventas por categoría:")
print(tienda["Categoría del Producto"].value_counts())
print()

print("Tienda 2 - Ventas por categoría:")
print(tienda2["Categoría del Producto"].value_counts())
print()
print("Tienda 3 - Ventas por categoría:")
print(tienda3["Categoría del Producto"].value_counts())
print()
print("Tienda 4 - Ventas por categoría:")
print(tienda4["Categoría del Producto"].value_counts())
print()
# Out:
# Tienda 1 - Ventas por categoría:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
#
# Tienda 2 - Ventas por categoría:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
#
# Tienda 3 - Ventas por categoría:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
print(tienda.columns)
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
prom_tienda1 = tienda["Calificación"].mean()
prom_tienda2 = tienda2["Calificación"].mean()
prom_tienda3 = tienda3["Calificación"].mean()
prom_tienda4 = tienda4["Calificación"].mean()

print(f"Calificación promedio - Tienda 1: {prom_tienda1:.2f}")
print(f"Calificación promedio - Tienda 2: {prom_tienda2:.2f}")
print(f"Calificación promedio - Tienda 3: {prom_tienda3:.2f}")
print(f"Calificación promedio - Tienda 4: {prom_tienda4:.2f}")
# Out:
# Calificación promedio - Tienda 1: 3.98
# Calificación promedio - Tienda 2: 4.04
# Calificación promedio - Tienda 3: 4.05
# Calificación promedio - Tienda 4: 4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
print(tienda.columns)
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

def analizar_ventas_por_producto(df, nombre_tienda):
    # Contar ventas por producto
    conteo = df["Producto"].value_counts()

    # Mostrar el más y menos vendido
    mas_vendido = conteo.idxmax()
    menos_vendido = conteo.idxmin()
    print(f"{nombre_tienda} - Producto más vendido: {mas_vendido} ({conteo.max()} ventas)")
    print(f"{nombre_tienda} - Producto menos vendido: {menos_vendido} ({conteo.min()} ventas)\n")

    # Gráfico de los 5 más vendidos
    top5 = conteo.head(5)
    plt.figure(figsize=(8, 4))
    top5.plot(kind="bar", color="skyblue")
    plt.title(f"{nombre_tienda} - Top 5 productos más vendidos")
    plt.ylabel("Cantidad de ventas")
    plt.xlabel("Producto")
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# Analizar cada tienda
analizar_ventas_por_producto(tienda, "Tienda 1")
analizar_ventas_por_producto(tienda2, "Tienda 2")
analizar_ventas_por_producto(tienda3, "Tienda 3")
analizar_ventas_por_producto(tienda4, "Tienda 4")
# Out:
# Tienda 1 - Producto más vendido: Microondas (60 ventas)
# Tienda 1 - Producto menos vendido: Auriculares con micrófono (33 ventas)
# Tienda 2 - Producto más vendido: Iniciando en programación (65 ventas)
# Tienda 2 - Producto menos vendido: Juego de mesa (32 ventas)
# Tienda 3 - Producto más vendido: Kit de bancas (57 ventas)
# Tienda 3 - Producto menos vendido: Bloques de construcción (35 ventas)
# Tienda 4 - Producto más vendido: Cama box (62 ventas)
# Tienda 4 - Producto menos vendido: Guitarra eléctrica (33 ventas)

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio1 = tienda["Costo de envío"].mean()
envio2 = tienda2["Costo de envío"].mean()
envio3 = tienda3["Costo de envío"].mean()
envio4 = tienda4["Costo de envío"].mean()

print(f"Costo de envío promedio - Tienda 1: ${envio1:.2f}")
print(f"Costo de envío promedio - Tienda 2: ${envio2:.2f}")
print(f"Costo de envío promedio - Tienda 3: ${envio3:.2f}")
print(f"Costo de envío promedio - Tienda 4: ${envio4:.2f}")
# Out:
# Costo de envío promedio - Tienda 1: $26018.61
# Costo de envío promedio - Tienda 2: $25216.24
# Costo de envío promedio - Tienda 3: $24805.68
# Costo de envío promedio - Tienda 4: $23459.46

# %%
ingresos = [
    tienda["Precio"].sum(),
    tienda2["Precio"].sum(),
    tienda3["Precio"].sum(),
    tienda4["Precio"].sum()
]

nombres_tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]


plt.figure(figsize=(8, 5))
plt.bar(nombres_tiendas, ingresos, color='lightgreen')
plt.title("Ingresos totales por tienda")
plt.ylabel("Ingresos ($)")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

calificaciones = [
    tienda["Calificación"].mean(),
    tienda2["Calificación"].mean(),
    tienda3["Calificación"].mean(),
    tienda4["Calificación"].mean()
]


plt.figure(figsize=(8, 5))
plt.plot(nombres_tiendas, calificaciones, marker='o', linestyle='-', color='royalblue')
plt.title("Calificación promedio por tienda")
plt.ylabel("Puntaje (1 a 5)")
plt.ylim(0, 5)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

print(tienda.columns)

categorias_t1 = tienda["Categoría del Producto"].value_counts()
plt.figure(figsize=(6, 6))
categorias_t1.plot(kind="pie", autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title("Distribución de ventas por categoría - Tienda 1")
plt.ylabel("")
plt.tight_layout()
plt.show()


categorias_t2 = tienda2["Categoría del Producto"].value_counts()
plt.figure(figsize=(6, 6))
categorias_t2.plot(kind="pie", autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title("Distribución de ventas por categoría - Tienda 2")
plt.ylabel("")
plt.tight_layout()
plt.show()


categorias_t3 = tienda3["Categoría del Producto"].value_counts()
plt.figure(figsize=(6, 6))
categorias_t3.plot(kind="pie", autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title("Distribución de ventas por categoría - Tienda 3")
plt.ylabel("")
plt.tight_layout()
plt.show()


categorias_t4 = tienda4["Categoría del Producto"].value_counts()
plt.figure(figsize=(6, 6))
categorias_t4.plot(kind="pie", autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title("Distribución de ventas por categoría - Tienda 4")
plt.ylabel("")
plt.tight_layout()
plt.show()


import matplotlib.pyplot as plt
import seaborn as sns


tienda["Tienda"] = "Tienda 1"
tienda2["Tienda"] = "Tienda 2"
tienda3["Tienda"] = "Tienda 3"
tienda4["Tienda"] = "Tienda 4"

df_tiendas = pd.concat([tienda, tienda2, tienda3, tienda4], ignore_index=True)


plt.figure(figsize=(10, 8))
sns.kdeplot(
    data=df_tiendas,
    x="lon", y="lat",
    fill=True, cmap="Reds", thresh=0.05, levels=100
)
plt.title("Mapa de Calor de Concentración de Ventas por Ubicación Geográfica")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')
